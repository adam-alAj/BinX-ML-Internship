# %% [markdown]
# # Day 1: Python & Data Scince Environment Setup
# This notebook documents the successful setup of the environment and libraries.

# %%
import numpy as np
import pandas as pd 
import matplotlib as mpl
import jupyter


print ("Numpy Version:", np.__version__)
print ("Pandas Version:", pd.__version__)
print ("matplotlib Version:", mpl.__version__)
# Out:
# Numpy Version: 2.5.1
# Pandas Version: 3.0.3
# matplotib Version: 3.11.1
